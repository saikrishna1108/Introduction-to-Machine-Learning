# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrishna1108/Introduction-to-Machine-Learning/blob/main/Homework6_1Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1 (40 pts):
#
# a. Develop a Fully Connected Neural Network with only one hidden layer (size of 32) to predict the housing value for the housing dataset. Make sure to include all input features. Compare your training loss value and validation results against the linear regression you implemented in Homework 5. Can you compare your model complexity (number of trainable parameters) against linear regression? Note: Perform 20%, and 80% split for training and validation.
#
#
#
# b. We will increase the network complexity by adding two additional hidden layers, the hidden layers overall. My suggestions for the size of layers are: 32, 64, 16, respectively. Please redesign the network and compare your training loss value and validation results against the linear regression you implemented in Homework 5 and Problem 1.a. Can you compare your model complexity? Note: Use the same 20%, and 80% split for training and validation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
import torch.optim as optim
torch.set_printoptions(edgeitems=2, linewidth=75)
torch.manual_seed(123)

# %%
Housing_data = pd.read_csv("/content/drive/MyDrive/Housing.csv")
Housing_data = Housing_data.replace({'yes':1,'no':0})
Housing_data['furnishingstatus'] =Housing_data['furnishingstatus'].map({'furnished':2,'semi-furnished':1,'unfurnished':0})
Housing_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 2

# %%
X = Housing_data.iloc[:,1:]
m = X.shape[0]
Y = np.array(Housing_data['price'])
Y = np.resize(Y,(len(Y),1))

# %%
sc = StandardScaler()
X = sc.fit_transform(X)
X.shape
# Out:
# (545, 12)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

Y_train = torch.from_numpy(Y_train).to(torch.float32)
X_train = torch.from_numpy(X_train).to(torch.float32)
Y_test = torch.from_numpy(Y_test).to(torch.float32)
X_test = torch.from_numpy(X_test).to(torch.float32)

# %%
def loss_fn(t_p, t_c):
    mse = torch.mean((t_p - t_c) ** 2)
    rmse = torch.sqrt(mse)
    return rmse

# %%
import torch.nn as nn
model=nn.Sequential(nn.Linear(12,32),
                        nn.Tanh(),
                        nn.Linear(32,1))
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# plt.plot(train_loss)
# plt.plot(val_loss)
# plt.legend(['Training Loss','Validation Loss'])

# %%
num_epochs = 1500
train_loss = []
val_loss = []
for epoch in range(num_epochs):
    model.train()
    outputs = model(X_train)
    loss = loss_fn(outputs,Y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epoch == 1 or epoch % 100 == 0:
        model.eval()
        with torch.no_grad():
            val = model(X_test)
            loss_val = loss_fn(val,Y_test)
            train_loss.append(loss.item())
            val_loss.append(loss_val.item())
            print(f'Epoch [{epoch}/{num_epochs}],  Training Loss: {loss.item():.2f}, Validation Loss: {loss_val.item():.2f}')
        model.train()
# Out:
# Epoch [0/1500],  Training Loss: 5145197.00, Validation Loss: 5015417.00
# Epoch [1/1500],  Training Loss: 5145197.00, Validation Loss: 5015417.00
# Epoch [100/1500],  Training Loss: 5145169.50, Validation Loss: 5015390.00
# Epoch [200/1500],  Training Loss: 5145142.00, Validation Loss: 5015363.50
# Epoch [300/1500],  Training Loss: 5145115.00, Validation Loss: 5015336.50
# Epoch [400/1500],  Training Loss: 5145087.00, Validation Loss: 5015309.50
# Epoch [500/1500],  Training Loss: 5145059.50, Validation Loss: 5015282.50
# Epoch [600/1500],  Training Loss: 5145032.00, Validation Loss: 5015255.50
# Epoch [700/1500],  Training Loss: 5145004.50, Validation Loss: 5015228.50
# Epoch [800/1500],  Training Loss: 5144977.50, Validation Loss: 5015201.50
# Epoch [900/1500],  Training Loss: 5144950.00, Validation Loss: 5015175.00
# Epoch [1000/1500],  Training Loss: 5144922.50, Validation Loss: 5015147.50
# Epoch [1100/1500],  Training Loss: 5144895.50, Validation Loss: 5015121.00
# Epoch [1200/1500],  Training Loss: 5144868.00, Validation Loss: 5015094.00
# Epoch [1300/1500],  Training Loss: 5144840.00, Validation Loss: 5015067.00
# Epoch [1400/1500],  Training Loss: 5144813.00, Validation Loss: 5015040.00
